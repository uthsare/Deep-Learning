# %%
#imports
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Define a function for plotting  Vector diagrams

# %%
def plotVectors(vectors):
  ax = plt.axes()
  #for loop to draw the vectors
  for vector in vectors :
    ax.arrow(0,0,*vector['vector'],head_width=0.05,color= vector['color'],head_length=0.1)
    plt.text(*(vector['vector']),vector['name'])

  plt.ylim(-4,4)
  plt.xlim(-4,4)

# %% [markdown]
# Examples

# %%
vectors = [
    {"vector": [1, 1], "name": "v1", "color": "red"},
    {"vector": [2, 0], "name": "v2", "color": "blue"},
    {"vector": [0, 3], "name": "v3", "color": "green"}
]

plotVectors(vectors)
plt.show()
